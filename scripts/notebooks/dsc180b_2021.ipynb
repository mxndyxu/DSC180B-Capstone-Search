# %% [markdown]
# All previous capstone projects:<br>
# https://docs.google.com/spreadsheets/d/1HJkTHUDJbfIPrPuMJ_DmWCvivxv5YU8Z_E8YCZao-84/edit#gid=511346602

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
# to scrape:
# https://dsc-capstone.org/archive/

# scrape differently for each year (website formatted differently)

# %%
# dataframe structure:
# year, project name, group members, mentor (what to do industry), website text, report text, github code url, poster url

# %%
# example scrape

# url = 'https://davidzyx.github.io/HinDroid-with-Embeddings/'
# response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')
# soup

# %%
# 2022-2023
# url22 = 'https://dsc-capstone.org/projects-2021-2022/'

url22 = "https://dsc-capstone.org/projects-2020-2021/"

# url22 = "https://dsc-capstone.org/projects-2019-2020/"
response22 = requests.get(url22)
soup22 = BeautifulSoup(response22.text, 'html.parser')

# %%
# soup22

# %%
tables = (soup22.find_all("div", {"id": "content"}))[1:]
len(tables)
# Out:
# 3

# %%
#Table 1: Areas of study

domains = []
mentors = []

aos = tables[0]
aos_tbody = aos.find("tbody")
aos_trs = aos_tbody.find_all("tr")
for tr in aos_trs:
    tds = tr.find_all("td")
#     print(tds)
    
#     print(tds[0].find("a").contents)
#     print(tds[1].contents)
    
    domains.append(tds[0].find("a").contents[0])
    mentors.append(tds[1].contents[0])
    
#     for td in tds:
#         print(td.contents)

# %%
domains, mentors
# Out:
# (['Explainable AI',
#   'Autonomous Vehicles',
#   'Malware and Graph Learning',
#   'Text Mining and NLP',
#   'Recommender Systems',
#   'Opioid Overdose Prevalence Analysis',
#   'Large-scale Multiple Testing',
#   'Spatial-temporal Analyses of Infectious Disease Dynamics',
#   'Graph Data Analysis',
#   'The Spread of Misinformation',
#   'Conflict and Collaboration in Online Communities',
#   'Genetic Basis of Mental Health',
#   'VPN X-Ray',
#   'Particle Physics',
#   'COVID-19 & Microbiome',
#   'Cyber-Physical Systems (CPS) using IOT Devices',
#   'System Usage Reporting (SUR, a.k.a. DCA)',
#   'Spatial Agent-based Modeling for School Reopening'],
#  ['Jurgen Schultze',
#   'Jack Silberman',
#   'Aaron Fraenkel',
#   'Jingbo Shang',
#   'Colin Jemmott',
#   'Amarnath Gutpa',
#   'Armin Schwartzman',
#   'Yian Ma',
#   'Gal Mishne',
#   'Justin Eldridge',
#   'Aaron Fraenkel',
#   'Shannon Ellis',
#   'Viasat',
#   'Frank Weuthwein & Javier Duarte',
#   'Rob Knight',
#   'Rajesh Gupta',
#   'Intel',
#   'Ilya Zaslavsky'])

# %%
# Table 3: In depth project details (idpd)

idpd = tables[2]

# %%
idpd_domains = idpd.find("div", {"class": "domain"})
idpd_domains
# Out:
# <div class="domain">
# <h3 id="Explainable AI">Explainable AI</h3>
# <hr>
# </hr></div>

# %%
#Project title

# %%
idpd_uls_names = idpd.find_all("ul")[0::2]
idpd_uls_links = idpd.find_all("ul")[1::2]

# %%
idpd_titles = (idpd.find_all("h4"))

# %%
title = []
group = []
links = []

for i in range(len(idpd_titles)):
    title.append(idpd_titles[i].text)
    print(i, idpd_titles[i].text)
    group.append(idpd_uls_names[i].find("li").text)
    print(i, idpd_uls_names[i].find("li").text)
#     print(i, idpd_uls[i + 1])
    
    lst = []
    for idpd_li in idpd_uls_links[i].find_all("li"):
        print(i, idpd_li.find("a")["href"])
        lst.append(idpd_li.find("a")["href"])
    links.append(lst)
    
    print("-" * 75)
# Out:
# 0 Determining Correct Face Mask Usage with Inception Resnet and MaskedFace-Net Dataset
# 0 Group members: Pratyush Juneja, Eric Kang, Minjoo Kim
# 0 https://elizabethmkim.github.io/FaceMaskDetection/
# 0 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_53/README.md
# 0 reports/project_53.pdf
# ---------------------------------------------------------------------------
# 1 Face Mask Detection with Explainable Artificial Intelligence
# 1 Group members: Gavin Tran, Athena Liu, Che-Wei Lin
# 1 https://athena112233.github.io/DSC180B_Project_Webpage/
# 1 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_52/README.md
# 1 reports/project_52.pdf
# ---------------------------------------------------------------------------
# 2 Explaining Image Captioning Models Through Attention Maps, Image
# Perturbations, and Object Importance Maps
# 2 Group members: Yuexiang Zhang, Alejandro Fosado, Jordan Levy
# 2 https://afosado.github.io/180b_capstone_xai/
# 2 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_51/README.md
# 2 reports/project_51.pdf
# ---------------------------------------------------------------------------
# 3 Image Recognition in Stock Prediction with Visual Explanations from Grad-CAM
# 3 Group members: Sohyun Lee, Shin Ehara, Jou-Ying Lee
# 3 https://connielee99.github.io/Explainable-AI-in-Finance/
# 3 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_50/README.md
# 3 reports/project_50.pdf
# ---------------------------------------------------------------------------
# 4 Demystifying Machine Learning for Facial Analysis
# 4 Group members: Ting Hung, Sudiksha Sarvepalli, Nicole Lee
# 4 https://michael4706.github.io/XAI_Website/
# 4 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_49/README.md
# 4 reports/project_49.pdf
# ---------------------------------------------------------------------------
# 5 Snake Classification using Neural-Backed Decision Trees
# 5 Group members: Rui Zheng, Weihua Zhao, Nikolas Racelis-Russell
# 5 https://nikolettuce.github.io/DSC180B_06_NeuralBackedDecisionTrees/
# 5 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_54/README.md
# 5 reports/project_54.pdf
# ---------------------------------------------------------------------------
# 6 Autoware and LGSVL
# 6 Group members: Andres Bernal, Amir Uqdah, Jie Wang
# 6 https://a3bernal.github.io/180-visualization/
# 6 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_16/README.md
# 6 reports/project_16.pdf
# ---------------------------------------------------------------------------
# 7 Computer Vision and Lane Segmentation in Autonomous Vehicles
# 7 Group members: Evan Kim, Joseph Fallon, Ka Chan
# 7 https://joseph-fallon.medium.com/dsc-180b-team-5-computer-vision-and-image-processing-for-autonomous-vehicles-applications-ee494d954093
# 7 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_15/README.md
# 7 reports/project_15.pdf
# ---------------------------------------------------------------------------
# 8 Autonomous Mapping, Localization and Navigation using Computer Vision as well as Tuning of Camera
# 8 Group members: Youngseo Do, Jay Chong, Siddharth Saha
# 8 https://sisaha9.github.io/camera_mapping_navigation_website/
# 8 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_14/README.md
# 8 reports/project_14.pdf
# ---------------------------------------------------------------------------
# 9 Data Visualizations and Interface For Autonomous Robots
# 9 Group members: Jia Shi, Seokmin Hong, Yuxi Luo
# 9 https://elvishelvis.github.io/
# 9 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_13/README.md
# 9 reports/project_13.pdf
# ---------------------------------------------------------------------------
# 10 GPS Based Autonomous Navigation on the 1/5th Scale
# 10 Group members: Shiyin Liang, Garrett Gibo, Neghena Faizyar
# 10 https://neghena.github.io/GPS_Autonomous_Nav/
# 10 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_12/README.md
# 10 reports/project_12.pdf
# ---------------------------------------------------------------------------
# 11 Autonomous: Odometry and IMU
# 11 Group members: Pranav Deshmane, Sally Poon
# 11 https://sallypoon.github.io/autonomousvehicles.github.io/
# 11 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_11/README.md
# 11 reports/project_11.pdf
# ---------------------------------------------------------------------------
# 12 Malware Detection
# 12 Group members: Yu-Chieh Chen, Ruoyu Liu, Yikai Hao
# 12 https://yikaihao.github.io/DSC180_Webpage/
# 12 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_55/README.md
# 12 reports/project_55.pdf
# ---------------------------------------------------------------------------
# 13 Potential Improvement of MAMADROID System
# 13 Group members: Zihan Qin, Jian Jiao
# 13 https://kamui-jiao.github.io/DSC180B-Page/
# 13 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_58/README.md
# 13 reports/project_58.pdf
# ---------------------------------------------------------------------------
# 14 Exploring the Language of Malware
# 14 Group members: Neel Shah, Mandy Ma
# 14 https://neels-hah.github.io/vector-embedding-exploration/
# 14 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_57/README.md
# 14 reports/project_57.pdf
# ---------------------------------------------------------------------------
# 15 CoCoDroid: Detecting Malware By Building Common Graph Using Control Flow Graph
# 15 Group members: Edwin Huang, Sabrina Ho
# 15 https://iamsabhoho.github.io/dsc180b-malware/
# 15 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_56/README.md
# 15 reports/project_56.pdf
# ---------------------------------------------------------------------------
# 16 Attacking the HinDroid Malware Detector
# 16 Group members: Ruben Gonzalez, Amar Joea
# 16 https://rcgonzalez9061.github.io/m2vDroid-blog/
# 16 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_59/README.md
# 16 reports/project_59.pdf
# ---------------------------------------------------------------------------
# 17 AutoPhrase Application Web
# 17 Group members: Tiange Wan, Yicen Ma, Anant Gandhi
# 17 https://white-wildflower-6469.fly.dev/python/
# 17 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_38/README.md
# 17 reports/project_38.pdf
# ---------------------------------------------------------------------------
# 18 Analyzing Movies Using Phrase Mining
# 18 Group members: Daniel Lee, Yuxuan Fan, Huilai Miao
# 18 https://a04-capstone-group-02.github.io/movie-analysis-webpage/
# 18 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_42/README.md
# 18 reports/project_42.pdf
# ---------------------------------------------------------------------------
# 19 AutoPhrase for Financial Documents Interpretation
# 19 Group members: Joey Hou, Shaoqing Yi, Zachary Ling
# 19 https://shy218.github.io/dsc180-project/
# 19 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_41/README.md
# 19 reports/project_41.pdf
# ---------------------------------------------------------------------------
# 20 Text Classification with Named-Entity Recognition and AutoPhrase
# 20 Group members: Siyu Deng, Rachel Ung, Yang Li
# 20 https://dsc180b-a04-capstone-group-06.github.io/News-Classification-Webpage/
# 20 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_40/README.md
# 20 reports/project_40.pdf
# ---------------------------------------------------------------------------
# 21 AutoLibrary - A Personal Digital Library to Find Related Works via Text Analyzer
# 21 Group members: Bingqi Zhou, Jiayi Fan, Yichun Ren
# 21 https://yichunren.pythonanywhere.com/autolibrary/
# 21 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_39/README.md
# 21 reports/project_39.pdf
# ---------------------------------------------------------------------------
# 22 Restaurant Recommender System
# 22 Group members: Shenghan Liu, Catherine Hou, Vincent Le
# 22 http://vil069.pythonanywhere.com/
# 22 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_37/README.md
# 22 reports/project_37.pdf
# ---------------------------------------------------------------------------
# 23 ForumRec - A Question Recommender for the Super User Community
# 23 Group members: Yo Jeremijenko-Conley, Jack Lin, Jasraj Johl
# 23 http://www.jackzlin.com/
# 23 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_48/README.md
# 23 reports/project_48.pdf
# ---------------------------------------------------------------------------
# 24 OnSight: Outdoor Rock Climbing Recommendations
# 24 Group members: Brent Min, Brian Cheng, Eric Liu
# 24 https://dsc180b-rc-rec.herokuapp.com/
# 24 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_47/README.md
# 24 reports/project_47.pdf
# ---------------------------------------------------------------------------
# 25 Bridging the Gap: Solving Music Disputes with Recommendation Systems
# 25 Group members: Nayoung Park, Sarat Sreepathy, Duncan Carlmark
# 25 http://bridgingthegapwithmusic.com/
# 25 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_46/README.md
# 25 reports/project_46.pdf
# ---------------------------------------------------------------------------
# 26 Asnapp - Workout Video Recommender
# 26 Group members: Peter Peng, Najeem Kanishka, Amanda Shu
# 26 https://workout-recommender.herokuapp.com/
# 26 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_45/README.md
# 26 reports/project_45.pdf
# ---------------------------------------------------------------------------
# 27 Plates4U
# 27 Group members: Zachary Nguyen, Alex Pham, Anthony Fong
# 27 https://recipe-rec-app.herokuapp.com/
# 27 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_43/README.md
# 27 reports/project_43.pdf
# ---------------------------------------------------------------------------
# 28 Makeup Recommender
# 28 Group members: Justin Lee, Shayal Singh, Alexandria Kim
# 28 https://makeup-recommender.herokuapp.com/
# 28 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_44/README.md
# 28 reports/project_44.pdf
# ---------------------------------------------------------------------------
# 29 Opioid Overdose Prevalence Analysis
# 29 Group members: Gunther Schwartz, Flory Huang, Hanbyul Ryu
# 29 http://137.110.40.139:8080/#/reddit
# 29 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_71/README.md
# 29 reports/project_71.pdf
# ---------------------------------------------------------------------------
# 30 Multiple Testing Method with Empirical Null Distribution in Leukemia Studies
# 30 Group members: Raymond Wang
# 30 https://xiw483.github.io/dsc180b-website/
# 30 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_63/README.md
# 30 reports/project_63.pdf
# ---------------------------------------------------------------------------
# 31 Large-scale Multiple Testing with Empirical Null Distribution in Predicting Cardiovascular Disease
# 31 Group members: Zimin Dai, Leyang Zhang, Wentao Chen
# 31 https://larryzly.github.io/CardiovascularClassifier/
# 31 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_77/README.md
# 31 reports/project_77.pdf
# ---------------------------------------------------------------------------
# 32 Spatial-temporal Prediction of COVID-19 Case Counts Through Epidemiology Model
# 32 Group members: Shuyuan Wang
# 32 https://shuyuan66.github.io/capstone_epidemiology__web/
# 32 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_29/README.md
# 32 reports/project_29.pdf
# ---------------------------------------------------------------------------
# 33 A Graph ML Analysis of Senatorial Twitter Accounts
# 33 Group members: Yueting Wu, Yimei Zhao, Anurag Pamuru
# 33 https://anuragpamuru.github.io/dsc-180b-capstone-b03
# 33 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_22/README.md
# 33 reports/project_22.pdf
# ---------------------------------------------------------------------------
# 34 GCN on 3d Points
# 34 Group members: Shang Li, Xinrui Zhan
# 34 https://ctwayen.github.io/Graph-Neural-Network-on-3D-Points/
# 34 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_20/README.md
# 34 reports/project_20.pdf
# ---------------------------------------------------------------------------
# 35 Graph-Based Product Recommendation
# 35 Group members: Abdullatif Jarkas, Nathan Tsai
# 35 https://nhtsai.github.io/graph-rec/
# 35 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_19/README.md
# 35 reports/project_19.pdf
# ---------------------------------------------------------------------------
# 36 NBA Game Prediction
# 36 Group members: Austin Le, Mengyuan Shi
# 36 https://austinle.github.io
# 36 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_18/README.md
# 36 reports/project_18.pdf
# ---------------------------------------------------------------------------
# 37 NBA Seeds with Graph Neural Networks
# 37 Group members: Steven Liu, Aurelio Barrios
# 37 https://sdevinl.github.io/DSC180B_Project/
# 37 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_21/README.md
# 37 reports/project_21.pdf
# ---------------------------------------------------------------------------
# 38 Stock Market Sentiment Predictor
# 38 Group members: Jason Chau, Sung-Lin Chang, Dylan Loe
# 38 https://sleasian.github.io/
# 38 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_76/README.md
# 38 reports/project_76.pdf
# ---------------------------------------------------------------------------
# 39 Political Popularity of Misinformation
# 39 Group members: Catherine Tao, Aaron Chan, Matthew Sao
# 39 https://baymatt.github.io/TwitterPoliticianMisinformation/
# 39 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_0/README.md
# 39 reports/project_0.pdf
# ---------------------------------------------------------------------------
# 40 The Sentiment of U.S. Presidential Elections on Twitter
# 40 Group members: Zahra Masood, Sravya Voleti, Hannah Peterson
# 40 https://hbpeters.github.io/2016-2020_pres_elections_twitter
# 40 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_1/README.md
# 40 reports/project_1.pdf
# ---------------------------------------------------------------------------
# 41 Community Effects From Misinformation Flags on Twitter
# 41 Group members: Nigel Doering, Tanuj Pankaj, Raechel Walker
# 41 https://raechelwalker.github.io/visual_presentation/
# 41 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_2/README.md
# 41 reports/project_2.pdf
# ---------------------------------------------------------------------------
# 42 Political Polarization of Major News Networks on Twitter
# 42 Group members: Christopher Ly, Shutong Li, Mark Chang
# 42 https://chrisly99.github.io/political_bots_site/
# 42 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_3/README.md
# 42 reports/project_3.pdf
# ---------------------------------------------------------------------------
# 43 Twitter’s Impact on Elections
# 43 Group members: Prem Pathuri, Zhi Lin
# 43 https://prem1835213.github.io/Election_Twitter/
# 43 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_4/README.md
# 43 reports/project_4.pdf
# ---------------------------------------------------------------------------
# 44 Analyzing the the Diffusions of Various Forms of Misinformation on Reddit
# 44 Group members: Cindy Huynh, Hasan Liou, Helen Chung
# 44 https://helenhc.github.io/reddit-site/
# 44 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_5/README.md
# 44 reports/project_5.pdf
# ---------------------------------------------------------------------------
# 45 COVID-19 Sentiment and Daily ases Analysis on Social Media
# 45 Group members: Jiawei Zheng, Yunlin Tang, Zhou Li
# 45 https://yunlintang.github.io/DSC180B-Blog/
# 45 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_6/README.md
# 45 reports/project_6.pdf
# ---------------------------------------------------------------------------
# 46 Controversy In Wikipedia Articles
# 46 Group members: Hengyu Liu, Xiangchen Zhao, Xingyu Jiang
# 46 https://zxchen98.github.io/Controversy_Visual_output/
# 46 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_25/README.md
# 46 reports/project_25.pdf
# ---------------------------------------------------------------------------
# 47 The Large-Scale Collaborative Presence of Online Fandoms
# 47 Group members: Casey Duong, Kylee Peng, Darren Liu
# 47 https://kyleepeng.github.io/Fandom-Online-Collaboration/
# 47 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_26/README.md
# 47 reports/project_26.pdf
# ---------------------------------------------------------------------------
# 48 Wikipedia’s Response to the COVID-19 Pandemic
# 48 Group members: Michael Lam, Gabrielle Avila, Yiheng Ye
# 48 https://ggavila.github.io/WikipediaProjectWebsite/
# 48 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_27/README.md
# 48 reports/project_27.pdf
# ---------------------------------------------------------------------------
# 49 A Study of LGBTQ+ Wikipedia Articles Sentiment over Time
# 49 Group members: Henry Lozada, Emma Logomasini, Parth Patel, Yuanbo Shi
# 49 https://dsc180b-group5.github.io/emmalogo.github.io/
# 49 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_23/README.md
# 49 reports/project_23.pdf
# ---------------------------------------------------------------------------
# 50 Politics on Wikipedia
# 50 Group members: Cameron Thomas, Iakov Vasilyev, Joseph Del-Val
# 50 https://mryanchos.github.io/PoW/
# 50 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_24/README.md
# 50 reports/project_24.pdf
# ---------------------------------------------------------------------------
# 51 Differential Gene Expression Analysis of Human Opioid Abusers
# 51 Group members: Cathleen Pena, Dennis Wu, Zhaoyi Guo
# 51 https://genetics.denncc.com/blog/2021/02/differential-gene-expression-analysis-of-human-opioid-abusers/
# 51 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_70/README.md
# 51 reports/project_70.pdf
# ---------------------------------------------------------------------------
# 52 The Genetic Basis of Antibiotic Resistance in E. Coli
# 52 Group members: Jiayi Wu, Alan Chen, Myra Haider
# 52 https://alandsc.github.io/GWAS/
# 52 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_68/README.md
# 52 reports/project_68.pdf
# ---------------------------------------------------------------------------
# 53 Blood-based Analysis of Alzheimer's Disease from miRNA Data
# 53 Group members: Gregory Thein, Justin Kang, Ryan Cummings
# 53 https://justjk139.github.io
# 53 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_67/README.md
# 53 reports/project_67.pdf
# ---------------------------------------------------------------------------
# 54 Comparison of Differential Gene Expression Analysis Tools
# 54 Group members: Brandon Tsui, Joseph Bui, Weijie Cheng
# 54 https://iLuigi98.github.io
# 54 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_66/README.md
# 54 reports/project_66.pdf
# ---------------------------------------------------------------------------
# 55 Genetic Overlap between Alzheimer's, Parkinson’s, and healthy patients
# 55 Group members: Xuanyu Wu, Justin Lu, Saroop Samra
# 55 https://xuanyuw.github.io/miRNA_overlap_AD_PD.github.io/
# 55 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_69/README.md
# 55 reports/project_69.pdf
# ---------------------------------------------------------------------------
# 56 Live vs. Video on Demand Inside VPN Detection
# 56 Group members: Da Gong, Mariam Qader, Andrey Pristinsky, Tianran Qiu, Zishun Jin
# 56 https://pristinsky1.github.io/live_vs_video_on_demand_VPN_detection/
# 56 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_9/README.md
# 56 reports/project_9.pdf
# ---------------------------------------------------------------------------
# 57 DANE: Data Automation and Network Emulation Tool
# 57 Group members: Danial Yaseen, Sahil Altekar, Parker Addison
# 57 https://dane-tool.github.io/dane/
# 57 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_8/README.md
# 57 reports/project_8.pdf
# ---------------------------------------------------------------------------
# 58 Res Recovery: Classifying Video Resolutions Through a VPN Tunnel
# 58 Group members: Samson Qian, Shrimant Singh, Soon Shin, Iman Nematollahi, Stephen Doan
# 58 https://stephdoan.github.io/ResRecovery/
# 58 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_7/README.md
# 58 reports/project_7.pdf
# ---------------------------------------------------------------------------
# 59 SPICIVPN
# 59 Group members: Arely Vasquez, Chang Yuan, Raimundo Castro, Jerry Qian, Molly Rowland
# 59 https://mhrowlan.github.io/streaming_provider_classifier_inside_vpn/
# 59 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_10/README.md
# 59 reports/project_10.pdf
# ---------------------------------------------------------------------------
# 60 Interpreting Higgs Boson Interaction Network with Layerwise Relevance Propagation
# 60 Group members: Alex Luo, Cecilia Xiao
# 60 https://hin-lrp.github.io/
# 60 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_65/README.md
# 60 reports/project_65.pdf
# ---------------------------------------------------------------------------
# 61 Deep Learning for Particle Jet Multiclassification
# 61 Group members: Nathan Roberts, Darren Chang, Sharmi Mathur
# 61 https://sharmimathur.github.io/multiclassification-particle-jets/
# 61 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_64/README.md
# 61 reports/project_64.pdf
# ---------------------------------------------------------------------------
# 62 RTL Automation
# 62 Group members: Richard Duong, Nick Lin, Yijian Zong
# 62 http://rtl-automation.herokuapp.com/
# 62 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_72/README.md
# 62 reports/project_72.pdf
# ---------------------------------------------------------------------------
# 63 AUTOBRICK: A system for end-to-end automation of building point labels to Brick turtle files
# 63 Group members: Advitya Gemawat, Devanshu Desai
# 63 https://devanshuDesai.github.io/AutoBrick/
# 63 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_60/README.md
# 63 reports/project_60.pdf
# ---------------------------------------------------------------------------
# 64 Airborne Infection Risk Estimator for COVID-19
# 64 Group members: Etienne Doidic, Zhexu Li, Nicholas Kho
# 64 https://hinanawits.github.io/DSC-180B-Presentation-Website/
# 64 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_61/README.md
# 64 reports/project_61.pdf
# ---------------------------------------------------------------------------
# 65 Mouse Wait Classification
# 65 Group members: Pan Yeung, Sijie Mei, Yingyin Xiao
# 65 https://panyeung.github.io/UserWaitVisual/
# 65 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_34/README.md
# 65 reports/project_34.pdf
# ---------------------------------------------------------------------------
# 66 Predicting Battery Remaining Minutes based Related Features
# 66 Group members: Jinzong Que, Yijun Liu, Kaixin Huang
# 66 https://k3huang.github.io/dsc180b-visual-presentation-/
# 66 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_33/README.md
# 66 reports/project_33.pdf
# ---------------------------------------------------------------------------
# 67 Persona Analysis
# 67 Group members: Ruotian Gao, Xin Yu, Weihang Gao
# 67 https://roygrt.github.io/Visual_presentation_180B/
# 67 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_35/README.md
# 67 reports/project_35.pdf
# ---------------------------------------------------------------------------
# 68 Predicting a User’s Persona Using Computer’s Specifications, CPU Utilization, CPU Temperature & Application Usage Time
# 68 Group members: Jon Zhang, Keshan Chen, Vince Wong
# 68 https://vlw003.github.io/
# 68 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_36/README.md
# 68 reports/project_36.pdf
# ---------------------------------------------------------------------------
# 69 Geographically Assisted Agent-based Model for COVID-19 Transmission (GeoACT)
# 69 Group members: Johnny Lei, Akshay Bhide, Evan Price, Kaushik Ganapathy
# 69 https://geoact.sdsc.edu/
# 69 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_32/README.md
# 69 reports/project_32.pdf
# ---------------------------------------------------------------------------
# 70 Modelling COVID-19 Transmission in San Diego School Buses
# 70 Group members: Ziqian Cui, Bernard Wong, Farhood Ensan, Areeb Syed
# 70 https://farhoodensan.github.io/BusPresentation/
# 70 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_31/README.md
# 70 reports/project_31.pdf
# ---------------------------------------------------------------------------
# 71 COVID-19 Spatial Agent-based Modeling: Single Room Infection
# 71 Group members: Eric Yu, Bailey Man, Songling Lu, Michael Kusnadi
# 71 https://ery010.github.io/OneRoomABMSite
# 71 https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_78/README.md
# 71 reports/project_78.pdf
# ---------------------------------------------------------------------------

# %%
links[0]
# Out:
# ['https://elizabethmkim.github.io/FaceMaskDetection/',
#  'https://github.com/DSC-Capstone/projects-2020-2021/tree/main/projects/project_53/README.md',
#  'reports/project_53.pdf']

# %%
group[0]
# Out:
# 'Group members: Pratyush Juneja, Eric Kang, Minjoo Kim'

# %%
member_lst = []
for g in group:
    members = g.split(":")[-1]
    member_lst.append([x.strip() for x in members.split(",")])

# %%
member_lst
# Out:
# [['Pratyush Juneja', 'Eric Kang', 'Minjoo Kim'],
#  ['Gavin Tran', 'Athena Liu', 'Che-Wei Lin'],
#  ['Yuexiang Zhang', 'Alejandro Fosado', 'Jordan Levy'],
#  ['Sohyun Lee', 'Shin Ehara', 'Jou-Ying Lee'],
#  ['Ting Hung', 'Sudiksha Sarvepalli', 'Nicole Lee'],
#  ['Rui Zheng', 'Weihua Zhao', 'Nikolas Racelis-Russell'],
#  ['Andres Bernal', 'Amir Uqdah', 'Jie Wang'],
#  ['Evan Kim', 'Joseph Fallon', 'Ka Chan'],
#  ['Youngseo Do', 'Jay Chong', 'Siddharth Saha'],
#  ['Jia Shi', 'Seokmin Hong', 'Yuxi Luo'],
#  ['Shiyin Liang', 'Garrett Gibo', 'Neghena Faizyar'],
#  ['Pranav Deshmane', 'Sally Poon'],
#  ['Yu-Chieh Chen', 'Ruoyu Liu', 'Yikai Hao'],
#  ['Zihan Qin', 'Jian Jiao'],
#  ['Neel Shah', 'Mandy Ma'],
#  ['Edwin Huang', 'Sabrina Ho'],
#  ['Ruben Gonzalez', 'Amar Joea'],
#  ['Tiange Wan', 'Yicen Ma', 'Anant Gandhi'],
#  ['Daniel Lee', 'Yuxuan Fan', 'Huilai Miao'],
#  ['Joey Hou', 'Shaoqing Yi', 'Zachary Ling'],
#  ['Siyu Deng', 'Rachel Ung', 'Yang Li'],
#  ['Bingqi Zhou', 'Jiayi Fan', 'Yichun Ren'],
#  ['Shenghan Liu', 'Catherine Hou', 'Vincent Le'],
#  ['Yo Jeremijenko-Conley', 'Jack Lin', 'Jasraj Johl'],
#  ['Brent Min', 'Brian Cheng', 'Eric Liu'],
#  ['Nayoung Park', 'Sarat Sreepathy', 'Duncan Carlmark'],
#  ['Peter Peng', 'Najeem Kanishka', 'Amanda Shu'],
#  ['Zachary Nguyen', 'Alex Pham', 'Anthony Fong'],
#  ['Justin Lee', 'Shayal Singh', 'Alexandria Kim'],
#  ['Gunther Schwartz', 'Flory Huang', 'Hanbyul Ryu'],
#  ['Raymond Wang'],
#  ['Zimin Dai', 'Leyang Zhang', 'Wentao Chen'],
#  ['Shuyuan Wang'],
#  ['Yueting Wu', 'Yimei Zhao', 'Anurag Pamuru'],
#  ['Shang Li', 'Xinrui Zhan'],
#  ['Abdullatif Jarkas', 'Nathan Tsai'],
#  ['Austin Le', 'Mengyuan Shi'],
#  ['Steven Liu', 'Aurelio Barrios'],
#  ['Jason Chau', 'Sung-Lin Chang', 'Dylan Loe'],
#  ['Catherine Tao', 'Aaron Chan', 'Matthew Sao'],
#  ['Zahra Masood', 'Sravya Voleti', 'Hannah Peterson'],
#  ['Nigel Doering', 'Tanuj Pankaj', 'Raechel Walker'],
#  ['Christopher Ly', 'Shutong Li', 'Mark Chang'],
#  ['Prem Pathuri', 'Zhi Lin'],
#  ['Cindy Huynh', 'Hasan Liou', 'Helen Chung'],
#  ['Jiawei Zheng', 'Yunlin Tang', 'Zhou Li'],
#  ['Hengyu Liu', 'Xiangchen Zhao', 'Xingyu Jiang'],
#  ['Casey Duong', 'Kylee Peng', 'Darren Liu'],
#  ['Michael Lam', 'Gabrielle Avila', 'Yiheng Ye'],
#  ['Henry Lozada', 'Emma Logomasini', 'Parth Patel', 'Yuanbo Shi'],
#  ['Cameron Thomas', 'Iakov Vasilyev', 'Joseph Del-Val'],
#  ['Cathleen Pena', 'Dennis Wu', 'Zhaoyi Guo'],
#  ['Jiayi Wu', 'Alan Chen', 'Myra Haider'],
#  ['Gregory Thein', 'Justin Kang', 'Ryan Cummings'],
#  ['Brandon Tsui', 'Joseph Bui', 'Weijie Cheng'],
#  ['Xuanyu Wu', 'Justin Lu', 'Saroop Samra'],
#  ['Da Gong', 'Mariam Qader', 'Andrey Pristinsky', 'Tianran Qiu', 'Zishun Jin'],
#  ['Danial Yaseen', 'Sahil Altekar', 'Parker Addison'],
#  ['Samson Qian',
#   'Shrimant Singh',
#   'Soon Shin',
#   'Iman Nematollahi',
#   'Stephen Doan'],
#  ['Arely Vasquez',
#   'Chang Yuan',
#   'Raimundo Castro',
#   'Jerry Qian',
#   'Molly Rowland'],
#  ['Alex Luo', 'Cecilia Xiao'],
#  ['Nathan Roberts', 'Darren Chang', 'Sharmi Mathur'],
#  ['Richard Duong', 'Nick Lin', 'Yijian Zong'],
#  ['Advitya Gemawat', 'Devanshu Desai'],
#  ['Etienne Doidic', 'Zhexu Li', 'Nicholas Kho'],
#  ['Pan Yeung', 'Sijie Mei', 'Yingyin Xiao'],
#  ['Jinzong Que', 'Yijun Liu', 'Kaixin Huang'],
#  ['Ruotian Gao', 'Xin Yu', 'Weihang Gao'],
#  ['Jon Zhang', 'Keshan Chen', 'Vince Wong'],
#  ['Johnny Lei', 'Akshay Bhide', 'Evan Price', 'Kaushik Ganapathy'],
#  ['Ziqian Cui', 'Bernard Wong', 'Farhood Ensan', 'Areeb Syed'],
#  ['Eric Yu', 'Bailey Man', 'Songling Lu', 'Michael Kusnadi']]

# %%
title[0]
# Out:
# 'Determining Correct Face Mask Usage with Inception Resnet and MaskedFace-Net Dataset'

# %%
len(title), len(domains), len(member_lst)
# Out:
# (72, 18, 72)

# %%
domain_freq = ([6,6, 5, 6, 6, 1, 2, 1, 6, 7, 5, 5, 4, 2, 1, 2, 4, 3])

# %%
sum(domain_freq), len(domain_freq)
# Out:
# (72, 18)

# %%
domain_lst = []
mentor_lst = []
for (x,y,z) in zip(domains, domain_freq, mentors):
    domain_lst += ([x] * y)
    mentor_lst += ([z] * y)

# %%
# domain_lst
# mentor_lst[:5]

# %%
project_urls = []
code_urls = []
reports = []

for link in links:
    project_urls.append(link[0])
    code_urls.append(link[1])
    reports.append("https://dsc-capstone.org/projects-2020-2021/" + link[2])

# %%
reports
# Out:
# ['https://dsc-capstone.org/projects-2020-2021/reports/project_53.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_52.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_51.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_50.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_49.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_54.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_16.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_15.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_14.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_13.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_12.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_11.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_55.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_58.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_57.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_56.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_59.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_38.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_42.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_41.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_40.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_39.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_37.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_48.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_47.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_46.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_45.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_43.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_44.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_71.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_63.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_77.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_29.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_22.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_20.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_19.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_18.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_21.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_76.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_0.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_1.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_2.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_3.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_4.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_5.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_6.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_25.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_26.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_27.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_23.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_24.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_70.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_68.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_67.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_66.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_69.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_9.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_8.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_7.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_10.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_65.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_64.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_72.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_60.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_61.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_34.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_33.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_35.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_36.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_32.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_31.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_78.pdf']

# %%
len(project_urls) == len(title)
# Out:
# True

# %%
title
# Out:
# ['Determining Correct Face Mask Usage with Inception Resnet and MaskedFace-Net Dataset',
#  'Face Mask Detection with Explainable Artificial Intelligence',
#  'Explaining Image Captioning Models Through Attention Maps, Image\nPerturbations, and Object Importance Maps',
#  'Image Recognition in Stock Prediction with Visual Explanations from Grad-CAM',
#  'Demystifying Machine Learning for Facial Analysis',
#  'Snake Classification using Neural-Backed Decision Trees',
#  'Autoware and LGSVL',
#  'Computer Vision and Lane Segmentation in Autonomous Vehicles',
#  'Autonomous Mapping, Localization and Navigation using Computer Vision as well as Tuning of Camera',
#  'Data Visualizations and Interface For Autonomous Robots',
#  'GPS Based Autonomous Navigation on the 1/5th Scale',
#  'Autonomous: Odometry and IMU',
#  'Malware Detection',
#  'Potential Improvement of MAMADROID System',
#  'Exploring the Language of Malware',
#  'CoCoDroid: Detecting Malware By Building Common Graph Using Control Flow Graph',
#  'Attacking the HinDroid Malware Detector',
#  'AutoPhrase Application Web',
#  'Analyzing Movies Using Phrase Mining',
#  'AutoPhrase for Financial Documents Interpretation',
#  'Text Classification with Named-Entity Recognition and AutoPhrase',
#  'AutoLibrary - A Personal Digital Library to Find Related Works via Text Analyzer',
#  'Restaurant Recommender System',
#  'ForumRec - A Question Recommender for the Super User Community',
#  'OnSight: Outdoor Rock Climbing Recommendations',
#  'Bridging the Gap: Solving Music Disputes with Recommendation Systems',
#  'Asnapp - Workout Video Recommender',
#  'Plates4U',
#  'Makeup Recommender',
#  'Opioid Overdose Prevalence Analysis',
#  'Multiple Testing Method with Empirical Null Distribution in Leukemia Studies',
#  'Large-scale Multiple Testing with Empirical Null Distribution in Predicting Cardiovascular Disease',
#  'Spatial-temporal Prediction of COVID-19 Case Counts Through Epidemiology Model',
#  'A Graph ML Analysis of Senatorial Twitter Accounts',
#  'GCN on 3d Points',
#  'Graph-Based Product Recommendation',
#  'NBA Game Prediction',
#  'NBA Seeds with Graph Neural Networks',
#  'Stock Market Sentiment Predictor',
#  'Political Popularity of Misinformation',
#  'The Sentiment of U.S. Presidential Elections on Twitter',
#  'Community Effects From Misinformation Flags on Twitter',
#  'Political Polarization of Major News Networks on Twitter',
#  'Twitter’s Impact on Elections',
#  'Analyzing the the Diffusions of Various Forms of Misinformation on Reddit',
#  'COVID-19 Sentiment and Daily ases Analysis on Social Media',
#  'Controversy In Wikipedia Articles',
#  'The Large-Scale Collaborative Presence of Online Fandoms',
#  'Wikipedia’s Response to the COVID-19 Pandemic',
#  'A Study of LGBTQ+ Wikipedia Articles Sentiment over Time',
#  'Politics on Wikipedia',
#  'Differential Gene Expression Analysis of Human Opioid Abusers',
#  'The Genetic Basis of Antibiotic Resistance in E. Coli',
#  "Blood-based Analysis of Alzheimer's Disease from miRNA Data",
#  'Comparison of Differential Gene Expression Analysis Tools',
#  "Genetic Overlap between Alzheimer's, Parkinson’s, and healthy patients",
#  'Live vs. Video on Demand Inside VPN Detection',
#  'DANE: Data Automation and Network Emulation Tool',
#  'Res Recovery: Classifying Video Resolutions Through a VPN Tunnel',
#  'SPICIVPN',
#  'Interpreting Higgs Boson Interaction Network with Layerwise Relevance Propagation',
#  'Deep Learning for Particle Jet Multiclassification',
#  'RTL Automation',
#  'AUTOBRICK: A system for end-to-end automation of building point labels to Brick turtle files',
#  'Airborne Infection Risk Estimator for COVID-19',
#  'Mouse Wait Classification',
#  'Predicting Battery Remaining Minutes based Related Features',
#  'Persona Analysis',
#  'Predicting a User’s Persona Using Computer’s Specifications, CPU Utilization, CPU Temperature & Application Usage Time',
#  'Geographically Assisted Agent-based Model for COVID-19 Transmission (GeoACT)',
#  'Modelling COVID-19 Transmission in San Diego School Buses',
#  'COVID-19 Spatial Agent-based Modeling: Single Room Infection']

# %%
posters = [None for i in range(len(domain_lst))]

# %%
projectsDF_2021 = pd.DataFrame({"Domain" : domain_lst, "Project" : title, "Mentors" : mentor_lst, "Members" : member_lst,
             "Report" : reports, "CodeRepo" : code_urls, "Website" : project_urls, "Posters" : posters})

# %%
projectsDF_2021.to_csv("projectsDF_2021.csv")

# %%
projectsDF_2021["Report"][0]
# Out:
# 'https://dsc-capstone.org/projects-2020-2021/reports/project_53.pdf'

# %%
reports
# Out:
# ['https://dsc-capstone.org/projects-2020-2021/reports/project_53.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_52.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_51.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_50.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_49.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_54.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_16.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_15.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_14.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_13.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_12.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_11.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_55.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_58.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_57.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_56.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_59.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_38.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_42.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_41.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_40.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_39.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_37.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_48.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_47.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_46.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_45.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_43.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_44.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_71.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_63.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_77.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_29.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_22.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_20.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_19.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_18.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_21.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_76.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_0.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_1.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_2.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_3.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_4.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_5.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_6.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_25.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_26.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_27.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_23.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_24.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_70.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_68.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_67.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_66.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_69.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_9.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_8.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_7.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_10.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_65.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_64.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_72.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_60.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_61.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_34.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_33.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_35.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_36.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_32.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_31.pdf',
#  'https://dsc-capstone.org/projects-2020-2021/reports/project_78.pdf']
